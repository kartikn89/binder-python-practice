# %% [markdown]
# ## Input and Output

# %%
ls
# Out:
# big.csv*       jupyterlab-slides.pdf  markdown_python.md  Untitled.ipynb
# data/          Lorenz.ipynb           notebooks/
# jupyterlab.md  lorenz.py              TCGA_Data/

# %%
print('hello kartik')
# Out:
# hello kartik

# %%
2*5
# Out:
# 10

# %%
print('dance')
# Out:
# dance

# %% [markdown]
# print('herllo')

# %%
print(2*4)
# Out:
# 8

# %%
kartik = 5

# %%
print(kartik)
# Out:
# 5

# %%
kartik = 'a'

# %%
print('hello world')
# Out:
# hello world

# %%
input('give me number')
# Out:
# give me number 23
# '23'

# %%
input ('show a number')
# Out:
# show a number 12
# '12'

# %%
name = input('Enter your name ')
print(name)
# Out:
# Enter your name  Franky
# Franky

# %%
print(name)
# Out:
# Franky

# %%
if(111>10):
    print(name)
# Out:
# Franky

# %% [markdown]
# ## Variables

# %%
x= '6'

# %% [markdown]
# float 1.9 , int 0-2^128 strings/chars

# %%
x = 5

# %% [markdown]
# y = 'a'

# %%
y='a'

# %%
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-39cb3db33052> in <module>
# ----> 1 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## Naming var

# %% [markdown]
# CamelCasing Variables --> lowerCaseUpperCase --> firstName
# lowercase_lowercase --> first_name

# %%
firstName = input('Enter your first name')
# Out:
# Enter your first name fsdfs

# %%
lastName = input('Enter your last name')
# Out:
# Enter your last name Chicken

# %%
print(firstName+' '+lastName)
# Out:
# Venky Chicken

# %% [markdown]
# a is different than A

# %%
LastName = 5

# %%
print(firstName + LastName)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d977a76a4f39> in <module>
# ----> 1 print(firstName + LastName)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Casting variables

# %%
x = 4.9

# %%
print(x)
# Out:
# 4.9

# %%
print(int(x))
# Out:
# 4

# %%
x = 4 #int value

# %%
print(str(x))
# Out:
# 4

# %%
z= int(3)

# %%
z = 'a'

# %% [markdown]
# Mutability and Immutability

# %% [markdown]
# Types

# %%
x= 5

# %%
print(x)
# Out:
# 5

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
k,l,m = "nsdxf",2,23.33

# %%
print(k)
# Out:
# nsdxf

# %%
print(l)
# Out:
# 2

# %%
k=l=m = "Kartik"

# %%
int(age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-6aeedcd4465f> in <module>
# ----> 1 int(age)
#
# NameError: name 'age' is not defined

# %%
fullName = input('Enter your full name ')
age = int(input('Enter your age '))
print('You entered your full name as '+fullName)
print('You age is ')
print (age)
print('fullName is variable type')
print(type(fullName))
print('age is variable type ')
print(type(age))
# Out:
# Enter your full name  gg
# Enter your age  33
# You entered your full name as gg
# You age is
# 33
# fullName is variable type
# <class 'str'>
# age is variable type
# <class 'int'>

# %% [markdown]
# print(type(age))

# %%
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# ## Conditions

# %%
if(5>1):
    print("hsdfsd")
# Out:
# hsdfsd

# %%
if(5>1):
    print("dsd")
else:
    print(4)
# Out:
# dsd

# %%
if(5>1):
    print(3)
if(5>2):
    print(34)
else:
    print(44)
# Out:
# 3
# 34

# %%
age = input('Enter your  age')
yourAge = int(age)
if(yourAge <= 21):
    print('You are a student')
elif((yourAge <60) and (yourAge >21)):
    print('You are a professional')
elif((yourAge >=60) and (yourAge < 100)):
    print('You are retired')
else:
    print('You are a ghost')
# Out:
# Enter your  age 65
# You are retired

# %%
inputName = input("Enter your name: ")
inputAge = input("How old are you? ")
inputWifeCount = input("How many wives do you have?:")
inputPersonIncome = input ("How much do you earn?")

taxPayable = 0
personAge = int(inputAge)
wifeCount = int(inputWifeCount)
personIncome = int(inputPersonIncome)

if((personAge >= 21) and (personAge < 31) and (wifeCount == 1)):
    taxPayable = 0.1*personIncome 
elif((personAge >= 31) and (personAge < 41) and (wifeCount == 1)):
    taxPayable = 0.2*personIncome 
elif((personAge >= 41) and (personAge < 51) and (wifeCount == 1)):
    taxPayable = 0.3*personIncome
elif((personAge >= 51) and (personAge < 61) and (wifeCount == 1)):
    taxPayable = 0.4*personIncome 
elif((personAge >=61) and (personAge < 71) and (wifeCount == 1)):
    taxPayable = 0.5*personIncome
elif((personAge >=71) and (personAge <75) and (wifeCount == 1)):
    taxPayable=0.6*personIncome
elif((personAge >=21) and (personAge <31) and (wifeCount == 2)):
    taxPayable = 0.1*personIncome 
elif((personAge >= 31) and (personAge < 41) and (wifeCount == 2)):
    taxPayable = 0.2*personIncome 
elif((personAge >= 41) and (personAge < 51) and (wifeCount == 2)):
    taxPayable = 0.3*personIncome
elif((personAge >= 51) and (personAge < 61) and (wifeCount == 2)):
    taxPayable = 0.4*personIncome 
elif((personAge >=61) and (personAge < 71) and (wifeCount == 2)):
    taxPayable = 0.5*personIncome
elif((personAge >=71) and (personAge <75) and (wifeCount == 2)):
    taxPayable=0.6*personIncome
else:
    taxPayable = 0
outputTax = str(taxPayable)
print(personName+" has to pay "+str(taxPayable)+" in taxes.")
